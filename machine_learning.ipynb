# %% [markdown]
# <div style="background:trasnparent url(machine_learning.png);width:100%;height:100%;"><br><br>
#     <center>
#         &emsp;  &emsp;
#         <button style="border:.5px; font-size:18px; background-color: transparent; color: rgb(248, 165, 13)">LOGO</button>
#         &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;
#         &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;
#         <a href="home.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238); text-decoration: none;">Home</a>
#         &emsp;  &emsp; &emsp;
#         <a href="data_science.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238); text-decoration: none;">Data Science</a> &emsp;  &emsp; &emsp;
#         <a href="machine_learning.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: white; text-decoration: none;">Machine Learning</a> &emsp;  &emsp; &emsp;
#         <a href="programming.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238); text-decoration: none;">Programming</a> &emsp;  &emsp; &emsp;
#         <br><br><br><br><br><br><br><br><br><br><br><br>
#     </center>
#     <br><br><br>
#     &emsp; &emsp;  &emsp; &emsp;
#     <span style='font-family:"Roboto";font-size:70px; color: rgb(117, 97, 238)' >Machine Learning</span><br><br>
#     &emsp; &emsp;  &emsp; &emsp;
#     <i><span style='font-family:"Roboto";font-size:17px; color: rgb(117, 97, 238)' > "Machine learning is the study of computer algorithms that improve <br>
#     &emsp; &emsp;  &emsp;
#     automatically through experience (Wikipedia)" </span> </i>
#     <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = "serif"

# %%
fig = plt.figure(figsize=(9, 6))
np.random.seed(100)
# Prepare data
x = np.random.normal(400, 50, 10_000)
y = np.random.normal(300, 50, 10_000)
c = np.random.rand(10_000)

# Draw the parent plot
ax = plt.scatter(x,y,s=5,c=c)
plt.xlim(400, 500)
plt.ylim(350, 400)
plt.xlabel('x', labelpad = 15)
plt.ylabel('y', labelpad = 15)

# Draw the inset subplot
ax_new = fig.add_axes([0.6, 0.6, 0.2, 0.2])
plt.scatter(x,y,s=1,c=c);
