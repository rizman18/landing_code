# %% [markdown]
# <div style="background:trasnparent url(home.png);width:100%;height:100%;"><br><br>
#     <center>
#       &emsp;  &emsp;
#       <button style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238)">LOGO</button>
#       &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;
#       &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp; &emsp;
#       <a href="home.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: white; text-decoration: none;">Home</a>
#       &emsp;  &emsp; &emsp;
#       <a href="data_science.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238); text-decoration: none;">Data Science</a> &emsp;  &emsp; &emsp;
#       <a href="machine_learning.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color:rgb(117, 97, 238); text-decoration: none;">Machine Learning</a> &emsp;  &emsp; &emsp;
#       <a href="programming.ipynb" class="button" style="border:.5px; font-size:18px; background-color: transparent; color: rgb(117, 97, 238); text-decoration: none;">Programming</a> &emsp;  &emsp; &emsp;
#     </center>
#     <br><br><br><br><br><br>
#     &emsp;  &emsp;  &emsp; &emsp;
#     <span style='font-family:"Roboto";font-size:40px; color: rgb(248, 165, 13)' >Welcome to</span><br><br><br>
#     &emsp;  &emsp;  &emsp; &emsp;
#     <span style='font-family:"Roboto";font-size:75px; color: rgb(117, 97, 238)' >Landing Code</span><br><br><br>
#     &emsp;  &emsp;  &emsp; &emsp;
#     <i><span style='font-family:"Roboto";font-size:20px; color: rgb(117, 97, 238)' > "An innovation in visualizing your code" </span> </i>
#     <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br> <br>
#     <br> <br> <br> <br> <br>
#     <center>
#     <table style="margin:5px; background-color: white; width:70%; font-size:25px;">
#         <tr style="background-color: white">
#         <center>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 1 </a></th>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 2 </a></th>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 3 </a></th>
#         </center>
#         </tr>
#         <tr style="background-color: white; font-size:15px">
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w1.png"> </a></td>
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w2.png"> </a></td>
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w3.png"> </a></td>
#         </tr>
#         <tr style="background-color: white; font-size:15px">
#             <td style="text-align:justify; padding: 10px 20px 20px 20px; "> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. </td>
#             <td style="text-align:justify; padding: 10px 20px 20px 20px;"> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. </td>
#             <td style="text-align:justify; padding: 10px 20px 20px 20px;"> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</td>
#         </tr>
#     </table>
#     <br><br>
#     <table style="margin:5px; background-color: white; width:70%; font-size:25px;">
#         <tr style="background-color: white">
#         <center>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 4 </a></th>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 5 </a></th>
#             <th style="text-align:center; "><a href="data_science.ipynb" style ="text-decoration: none; color: rgb(117, 97, 238)">Article 6 </a></th>
#         </center>
#         </tr>
#         <tr style="background-color: white; font-size:15px">
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w4.png"> </a></td>
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w5.png"> </a></td>
#             <td style="text-align:center; padding: 10px 20px 20px 20px;"><a href="data_science.ipynb" style ="text-decoration: none;"><img src="w6.png"> </a></td>
#         </tr>
#         <tr style="background-color: white; font-size:15px">
#             <td style="text-align:justify; padding: 10px 20px 20px 20px;"> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. </td>
#             <td style="text-align:justify; padding: 10px 20px 20px 20px;"> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. </td>
#             <td style="text-align:justify; padding: 10px 20px 20px 20px;"> &emsp; Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</td>
#         </tr>
#     </table>
#     <br> <br> <br> <br> <br>
#     <span style="color: white">Copyright &#169; 2020. Allrights reserved. </span>  <br>
#     </center>
#     <br> <br>
# </div>
